# %% [markdown]
# # Plotting
#
# Using a csv file with world development information, we are going to tell a story via plotting data.

# %% [markdown]
# First, let's import a couple packages to make this project easier.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Read the csv file into a pandas dataframe and view the first few rows.

# %%
pop_minder = pd.read_csv('gapminder.csv')

# The head function outputs the first few rows.
pop_minder.head(15)
# Out:
#     Unnamed: 0                 country  year   population      cont  life_exp  \
# 0           11             Afghanistan  2007   31889923.0      Asia    43.828
# 1           23                 Albania  2007    3600523.0    Europe    76.423
# 2           35                 Algeria  2007   33333216.0    Africa    72.301
# 3           47                  Angola  2007   12420476.0    Africa    42.731
# 4           59               Argentina  2007   40301927.0  Americas    75.320
# 5           71               Australia  2007   20434176.0   Oceania    81.235
# 6           83                 Austria  2007    8199783.0    Europe    79.829
# 7           95                 Bahrain  2007     708573.0      Asia    75.635
# 8          107              Bangladesh  2007  150448339.0      Asia    64.062
# 9          119                 Belgium  2007   10392226.0    Europe    79.441
# 10         131                   Benin  2007    8078314.0    Africa    56.728
# ...

# %% [markdown]
# We can also view the last 10 items in the dataframe using the .tail() method.

# %%
pop_minder.tail(10)
# Out:
#      Unnamed: 0             country  year   population      cont  life_exp  \
# 132        1595              Uganda  2007   29170398.0    Africa    51.542
# 133        1607      United Kingdom  2007   60776238.0    Europe    79.425
# 134        1619       United States  2007  301139947.0  Americas    78.242
# 135        1631             Uruguay  2007    3447496.0  Americas    76.384
# 136        1643           Venezuela  2007   26084662.0  Americas    73.747
# 137        1655             Vietnam  2007   85262356.0      Asia    74.249
# 138        1667  West Bank and Gaza  2007    4018332.0      Asia    73.422
# 139        1679         Yemen, Rep.  2007   22211743.0      Asia    62.698
# 140        1691              Zambia  2007   11746035.0    Africa    42.384
# 141        1703            Zimbabwe  2007   12311143.0    Africa    43.487
#
#           gdp_cap
# 132   1056.380121
# 133  33203.261280
# 134  42951.653090
# 135  10611.462990
# 136  11415.805690
# 137   2441.576404
# ...

# %%
type(pop_minder)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Use the .shape method to view the size of the data (rows, columns).

# %%
pop_minder.shape
# Out:
# (142, 7)

# %% [markdown]
# The .describe() method provides descriptive statistics about the numeric columns from the dataframe.

# %%
pop_minder.describe()
# Out:
#         Unnamed: 0    year    population    life_exp       gdp_cap
# count   142.000000   142.0  1.420000e+02  142.000000    142.000000
# mean    857.000000  2007.0  4.402122e+07   67.007423  11680.071820
# std     493.631441     0.0  1.476214e+08   12.073021  12859.937337
# min      11.000000  2007.0  1.995790e+05   39.613000    277.551859
# 25%     434.000000  2007.0  4.508034e+06   57.160250   1624.842248
# 50%     857.000000  2007.0  1.051753e+07   71.935500   6124.371109
# 75%    1280.000000  2007.0  3.121004e+07   76.413250  18008.835640
# max    1703.000000  2007.0  1.318683e+09   82.603000  49357.190170

# %% [markdown]
# Return a boolean indicating whether the country has an average life expectancy over 81.

# %%
pop_minder.life_exp > 81
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# Name: life_exp, Length: 142, dtype: bool

# %% [markdown]
# Use the boolean of life expectancy to display the countries.

# %%
pop_minder[pop_minder.life_exp > 81]
# Out:
#      Unnamed: 0           country  year   population     cont  life_exp  \
# 5            71         Australia  2007   20434176.0  Oceania    81.235
# 55          671  Hong Kong, China  2007    6980412.0     Asia    82.208
# 57          695           Iceland  2007     301931.0   Europe    81.757
# 66          803             Japan  2007  127467972.0     Asia    82.603
# 123        1487       Switzerland  2007    7554661.0   Europe    81.701
#
#          gdp_cap
# 5    34435.36744
# 55   39724.97867
# 57   36180.78919
# 66   31656.06806
# 123  37506.41907

# %% [markdown]
# Do the same to display the countries with life expectancy lower than 50.

# %%
pop_minder[pop_minder.life_exp < 50]
# Out:
#      Unnamed: 0                   country  year   population    cont  \
# 0            11               Afghanistan  2007   31889923.0    Asia
# 3            47                    Angola  2007   12420476.0  Africa
# 17          215                   Burundi  2007    8390505.0  Africa
# 21          263  Central African Republic  2007    4369038.0  Africa
# 27          335          Congo, Dem. Rep.  2007   64606759.0  Africa
# 30          371             Cote d'Ivoire  2007   18013409.0  Africa
# 52          635             Guinea-Bissau  2007    1472041.0  Africa
# 73          887                   Lesotho  2007    2012649.0  Africa
# 74          899                   Liberia  2007    3193942.0  Africa
# 77          935                    Malawi  2007   13327079.0  Africa
# 86         1043                Mozambique  2007   19951656.0  Africa
# 94         1139                   Nigeria  2007  135031164.0  Africa
# 107        1295                    Rwanda  2007    8860588.0  Africa
# ...

# %% [markdown]
# Return a boolean that indicates if a country's GDP per capita is over $40k

# %%
pop_minder.gdp_cap > 40000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 137    False
# 138    False
# 139    False
# 140    False
# 141    False
# Name: gdp_cap, Length: 142, dtype: bool

# %% [markdown]
# Display countries using the booleans from above.

# %%
pop_minder[pop_minder.gdp_cap > 40000]
# Out:
#      Unnamed: 0        country  year   population      cont  life_exp  \
# 62          755        Ireland  2007    4109086.0    Europe    78.885
# 71          863         Kuwait  2007    2505559.0      Asia    77.588
# 95         1151         Norway  2007    4627926.0    Europe    80.196
# 113        1367      Singapore  2007    4553009.0      Asia    79.972
# 134        1619  United States  2007  301139947.0  Americas    78.242
#
#          gdp_cap
# 62   40675.99635
# 71   47306.98978
# 95   49357.19017
# 113  47143.17964
# 134  42951.65309

# %% [markdown]
# Do the same thing for GDP per capita of less than $700.

# %%
pop_minder[pop_minder.gdp_cap < 700]
# Out:
#      Unnamed: 0           country  year  population    cont  life_exp  \
# 17          215           Burundi  2007   8390505.0  Africa    49.580
# 27          335  Congo, Dem. Rep.  2007  64606759.0  Africa    46.462
# 41          503           Eritrea  2007   4906585.0  Africa    58.040
# 42          515          Ethiopia  2007  76511887.0  Africa    52.947
# 52          635     Guinea-Bissau  2007   1472041.0  Africa    46.388
# 74          899           Liberia  2007   3193942.0  Africa    45.678
# 93         1127             Niger  2007  12894865.0  Africa    56.867
# 141        1703          Zimbabwe  2007  12311143.0  Africa    43.487
#
#         gdp_cap
# 17   430.070692
# 27   277.551859
# 41   641.369524
# 42   690.805576
# 52   579.231743
# 74   414.507341
# 93   619.676892
# 141  469.709298

# %% [markdown]
# Group by continent and display the mean GDP.

# %%
pop_minder.groupby('cont').gdp_cap.mean()
# Out:
# cont
# Africa       3089.032605
# Americas    11003.031625
# Asia        12473.026870
# Europe      25054.481636
# Oceania     29810.188275
# Name: gdp_cap, dtype: float64

# %% [markdown]
# Group by coninent and display the mean life expectancy.

# %%
pop_minder.groupby('cont').life_exp.mean()
# Out:
# cont
# Africa      54.806038
# Americas    73.608120
# Asia        70.728485
# Europe      77.648600
# Oceania     80.719500
# Name: life_exp, dtype: float64

# %%
# From the pop_minder DataFrame, we create two lists.  
#One for GDP per capita and another for life expectancy.
gdp_cap = list(pop_minder.gdp_cap)
life_exp = list(pop_minder.life_exp)

# %%
# Basic scatter plot
plt.scatter(x = gdp_cap, y = life_exp)

# Display the plot
plt.show()

# %%
# Log scale
plt.scatter(gdp_cap, life_exp)
plt.xscale('log')

# Display the plot
plt.show()

# %%
# Scatter plot
plt.scatter(gdp_cap, life_exp)
plt.xscale('log') 

# Add customizations
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

# Definition of tick_val and tick_lab
tick_val = [1000,10000,100000]
tick_lab = ['1k','10k','100k']

# Adapt the ticks on the x-axis
plt.xticks(tick_val, tick_lab)

# After customizing, display the plot
plt.show()

# %%
# Import numpy as np
import numpy as np

# Store pop as a numpy array: np_pop
pop = list(pop_minder.population/1000000)
np_pop = np.array(pop)

# Double np_pop
np_pop = np_pop * 2

# Update: set s argument to np_pop
plt.scatter(gdp_cap, life_exp, s = np_pop)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000],['1k', '10k', '100k'])

# Display the plot
plt.show()

# %%
dict = {
    'Asia':'red',
    'Europe':'green',
    'Africa':'yellow',
    'Americas':'purple',
    'Oceania':'blue'
}

cont = list(pop_minder.cont)

col = [dict[x] for x in cont]

# Specify c and alpha inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop)*2 , c = col, alpha = 0.65)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])

# Show the plot
plt.show()
# print(col)

# %%
# Specify c and alpha inside plt.scatter()
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha = 0.75)

# Previous customizations
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['$1k','$10k','$100k'])

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(4500, 80, 'China')
plt.text(42951, 82, 'US' )
plt.text(15000, 82, 'Japan')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()
